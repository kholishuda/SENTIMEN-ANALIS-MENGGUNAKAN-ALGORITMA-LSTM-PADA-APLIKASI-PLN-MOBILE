# %%
# KONESI COLAB KE DRIVE
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install tensorflow==2.13.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 524.1/524.1 MB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 78.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 93.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 107.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.8/440.8 kB 9.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: keras
#     Found existing installation: keras 3.4.1
#     Uninstalling keras-3.4.1:
#       Successfully uninstalled keras-3.4.1
#   Attempting uninstall: gast
# ...

# %%
# MENGHUBUNGKAN KE GPU RUNTIME (KARENA MEMAKAI DEEP LEARNING)
! nvidia-smi
# Out:
# Mon Aug 12 15:47:15 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8               9W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# **SCRAPPING**

# %%
# MENGINSTAL LIBRARY GOOGLE PLAY SCRAPPER UNTUK MELAKUKAN PROSES DOWNLOAD DATA (SCRAPPING) ULASAN PLN MOBILE
# !pip install google_play_scraper

# %%
# MENGIMPORT LIBRARY YANG SUDAH DIINSTAL SEBELUMNYA YAITU LIBRARY GOOGLE SCRAPPER
from google_play_scraper import Sort,reviews_all
import pandas as pd

# %%
# MELAKUKAN DOWNLOAD DATA (SCRAPPING) PADA APLIKASI PLN MOBILE YANG ADA DI PLAYSOTRE DENGAN ID APLIKASI YAITU : 'com.icon.pln123'
# DENGAN FORMAT FILE BAHASA INDONESIA , NEGARA INDONESIA, DAN MENGAMBIL SEMUA DATA
scrapreview=reviews_all(
    'com.icon.pln123',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    filter_score_with=None
)

# %%
# MENAMPILKAN HASIL SCRAPPING
app_reviews_df=pd.DataFrame(scrapreview)
app_reviews_df.info()

# %%
# KODE DIATAS HANYALAH CONTOH RUNNING SAJA UNTUK PROSES SCRAPPING
# MAKA KAMI AKAN MENGGUNAKAN DATA SCRAPPING YANG SUDAH KAMI LAKUKAN SEBELUMNYA
# DIBAWAH INI ADALAH KODE UNTUK MEMBACA FILE YANG AKAN DIGUNAKAN
import pandas as pd
path = "/content/drive/MyDrive/FILE TUGAS AKHIR/PLN.csv"
df = pd.read_csv(path)
df.sample(5)
# Out:
#                                     reviewId         userName  \
# 74777   182d8b11-80cc-4f3e-b47a-3d4c06200cbd   Rinaldi Ikhsan
# 113040  94080d9e-e5ca-41fe-a4cf-71e52141f8d9  Pengguna Google
# 56626   8d76cd80-481f-43a0-8b69-262a0cc2e910        Habib Cr0
# 116597  5a311d25-5a1d-4b6c-8874-0a100bde8ae6        Nurul Haq
# 107950  c480315f-cac9-483b-aed5-92659b2b717a      pasang baru
#
#                                                 userImage  \
# 74777   https://play-lh.googleusercontent.com/a-/ALV-U...
# 113040  https://play-lh.googleusercontent.com/EGemoI2N...
# 56626   https://play-lh.googleusercontent.com/a-/ALV-U...
# 116597  https://play-lh.googleusercontent.com/a-/ALV-U...
# 107950  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                                   content  score  \
# 74777   Super mantap.. Sangat membantu untuk pengaduan...      5
# 113040                                    Gak bisa dibuka      1
# ...

# %%
# DIBAWAH INI MERUPAKAN KETERANGAN MENGENAI DATA FRAME DAN JUMLAH DATA ULASAN APLIKASI PLN MOBILE DARI TAHUN 2021 - 2023
df.info()
print("\nDAPAT DILIHAT PADA REVIEW ID TERDAPAT JUMLAH DATA ULASAN YAITU 134325 DATA ULASAN")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134325 entries, 0 to 134324
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reviewId              134325 non-null  object
#  1   userName              134325 non-null  object
#  2   userImage             134325 non-null  object
#  3   content               134325 non-null  object
#  4   score                 134325 non-null  int64
#  5   thumbsUpCount         134325 non-null  int64
#  6   reviewCreatedVersion  118043 non-null  object
#  7   at                    134325 non-null  object
#  8   replyContent          132851 non-null  object
#  9   repliedAt             132851 non-null  object
#  10  appVersion            118043 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 11.3+ MB
#
# DAPAT DILIHAT PADA REVIEW ID TERDAPAT JUMLAH DATA ULASAN YAITU 134325 DATA ULASAN

# %% [markdown]
# **FILTERING**

# %%
# FILTER DATA INI MERUPAKAN PROSES PENGAMBILAN DATA YANG AKAN DIBUTUHKAN SAJA
# BEBERAPA DATA YANG AKAN KAMI BUTUHKAN YAITU : ULASAN, SCORE, TANGGAL
# MAKA SELAIN DATA ITU AKAN KAMI HAPUS
# DIBAWAH INI ADALAH KODE MENGINSTAL LIBRARY PANDAS UNTUK MELAKUKAN FILTER DATA
# !pip install pandas

# %%
# DIBAWAH INI MERUPAKAN KODE UNTUK IMPORT LIBRARY PANDAS DAN KODE UNTUK MENGILANGKAN DATA FRAME (KOLOM) YANG TIDAK DIPERLUKAN
import pandas as pd

# KODE UNTUK FILE YANG DIGUNAKAN
file_path = '/content/drive/MyDrive/FILE TUGAS AKHIR/PLN.csv'

# Baca file CSV ke dalam DataFrame
PLN = pd.read_csv(file_path)

# KODE UNTUK MENULISKAN DATA FRAME YANG AKAN DIHAPUS
kolom_yang_ingin_dihilangkan = ['userImage', 'reviewId', 'userName','thumbsUpCount','reviewCreatedVersion','replyContent','repliedAt','appVersion']

# Hapus kolom yang tidak diperlukan
PLN = df.drop(columns=kolom_yang_ingin_dihilangkan)

print("\nDATA DIBWAH INI MERUPAKAN HASIL FILTER PENGHAPUSAN DATA FRAME YANG TIDAK DIPERLUKAN :")
PLN.sample(5)
# Out:
# DATA DIBWAH INI MERUPAKAN HASIL FILTER PENGHAPUSAN DATA FRAME YANG TIDAK DIPERLUKAN :
#                                                   content  score  \
# 98401                         Aplikasinya makin bagusssss      5
# 32721   bagus aplikasinya, bisa bayar disini, laporan ...      5
# 118147                                  Sangat bermanfaat      5
# 91631   App nya sngat membantu bagi pelanggan. fitur a...      5
# 91350                Lebih baik lagi,,lagi dan lagi....👍👍      5
#
#                          at
# 98401   2023-01-21 07:36:21
# 32721   2023-05-16 13:20:21
# 118147  2021-06-25 10:01:16
# 91631   2022-11-28 08:20:41
# 91350   2023-05-31 05:06:28

# %%
# KODE DIBAWAH INI MERUPAKAN KODE MENDOWNLOAD DATA YANG SUDAH DIHAPUS KOLOM YANG TIDAK DIPERLUKAN
PLN.to_csv('/content/drive/MyDrive/FILE TUGAS AKHIR/PLN 1.csv', index=False)
print("\nFile CSV baru berhasil disimpan.")
# Out:
# File CSV baru berhasil disimpan.

# %%
# PADA DATA FRAME AT TIDAK DIHAPUS DIKARENAKAN UNTUK MELAKUKAN FILTER DATA SELANJUTNYA
# YAITU MENGAMBIL DATA ULASAN PLN MOBILE HANYA 1 TAHUN TERAKHIR PADA 01-01-2022 s/d 31-12-2022
# DIBAWAH INI ADALAH KODE UNTUK MELAKUKAN FILTER DATA TERSEBUT
import pandas as pd

# FILE YANG SUDAH DI FILTER 3 KOLOM
file_path = '/content/drive/MyDrive/FILE TUGAS AKHIR/PLN 1.csv'

# Baca file CSV ke dalam DataFrame
df= pd.read_csv(file_path)

# Mengubah kolom 'Tanggal' menjadi tipe data datetime
df['at'] = pd.to_datetime(df['at'])

# Menentukan rentang tanggal yang diinginkan
start_date = '2022-01-01'
end_date = '2022-12-31'

# Filtering data berdasarkan rentang tanggal
filtered_df = df[(df['at'] >= start_date) & (df['at'] <= end_date)]

# Menampilkan DataFrame setelah filtering
print("\nDIBAWAH INI ADALAH DATA ULASAN PLN MOBILE PADA TAHUN 2022 :")
filtered_df.head(5)
# Out:
# DIBAWAH INI ADALAH DATA ULASAN PLN MOBILE PADA TAHUN 2022 :
#                                                 content  score  \
# 5287  Proses transaksinya lama, padahal sudah transf...      1
# 5288  Aplikasi nya sudah bagus, memudahkan kita dala...      5
# 5289  Aplikasi ini sangat memudahkan, bisa di gunaka...      5
# 5290  Aplikasi serta pelayanan cukup bagus dan sigap...      4
# 5484  Naikin daya prosesnya invalid terus, ngulang b...      1
#
#                       at
# 5287 2022-06-02 12:30:21
# 5288 2022-09-30 01:21:02
# 5289 2022-09-01 10:00:16
# 5290 2022-02-15 05:43:56
# 5484 2022-08-27 11:23:26

# %%
filtered_df.to_csv('/content/drive/MyDrive/FILE TUGAS AKHIR/PLN 2.csv', index=False)
print("\nFILE SUDAH DIDOWNLOAD DAN BERIKUT KETERANGAN FILENYA :")
filtered_df.info()
# Out:
# FILE SUDAH DIDOWNLOAD DAN BERIKUT KETERANGAN FILENYA :
# <class 'pandas.core.frame.DataFrame'>
# Index: 40043 entries, 5287 to 134324
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  40043 non-null  object
#  1   score    40043 non-null  int64
#  2   at       40043 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 1.2+ MB

# %%
# KARENA DATA FRAME AT (KOLOM TANGGAL ULASAN) SUDAH TIDAK DIPERLUKAN , MAKA AKAN DIHAPUS
# BERIKUT KODE UNTUK MENGHAPUS KOLOM AT
#Menghapus kolom at pada data
import pandas as pd


# Ganti dengan path file CSV yang ingin Anda olah
file_path = '/content/drive/MyDrive/FILE TUGAS AKHIR/PLN 2.csv'

# Baca file CSV ke dalam DataFrame
df = pd.read_csv(file_path)

# Ganti dengan daftar nama kolom yang ingin dihilangkan
kolom_yang_ingin_dihilangkan = ['at']

# Hapus kolom yang tidak diperlukan
df = df.drop(columns=kolom_yang_ingin_dihilangkan)

# Tampilkan DataFrame setelah penghapusan kolom
print("\nBERIKUT HASIL PENGHAPUSAN KOLOM AT :")
df.head(5)
# Out:
# BERIKUT HASIL PENGHAPUSAN KOLOM AT :
#                                              content  score
# 0  Proses transaksinya lama, padahal sudah transf...      1
# 1  Aplikasi nya sudah bagus, memudahkan kita dala...      5
# 2  Aplikasi ini sangat memudahkan, bisa di gunaka...      5
# 3  Aplikasi serta pelayanan cukup bagus dan sigap...      4
# 4  Naikin daya prosesnya invalid terus, ngulang b...      1

# %%
df.to_csv('/content/drive/MyDrive/FILE TUGAS AKHIR/PLN 3.csv', index=False)
print("\nPROSES FILTER DATA SELESAI DATA SUDAH DIDOWNLOAD, BERIKUT KETERANGAN DATANYA :")
df.info()
# Out:
# PROSES FILTER DATA SELESAI DATA SUDAH DIDOWNLOAD, BERIKUT KETERANGAN DATANYA :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40043 entries, 0 to 40042
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  40043 non-null  object
#  1   score    40043 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 625.8+ KB

# %% [markdown]
# **LABELING**

# %%
# Pada tahap pelabelan data saya akan melabelisasi data berdasarkan nilai pada data frame score
# nilai 1-2 merupakan sentimen negatif
# nilai 3-5 merupakan sentimen positif
import pandas as pd

# Fungsi untuk pelabelan data
def label_data(score):
    if score < 3:
        return 'negative'
    elif score >= 3 and score <= 5:
        return 'positive'
    else:
        return 'nilai tidak valid'


df = pd.read_csv('/content/drive/MyDrive/FILE TUGAS AKHIR/PLN 3.csv')
# Ganti 'nama_file.csv' dengan nama file CSV yang sebenarnya

# Menerapkan fungsi pelabelan pada kolom 'score'
df['sentimen'] = df['score'].apply(label_data)

# Tampilkan data setelah pemberian label
df.head(5)
# Out:
#                                              content  score  sentimen
# 0  Proses transaksinya lama, padahal sudah transf...      1  negative
# 1  Aplikasi nya sudah bagus, memudahkan kita dala...      5  positive
# 2  Aplikasi ini sangat memudahkan, bisa di gunaka...      5  positive
# 3  Aplikasi serta pelayanan cukup bagus dan sigap...      4  positive
# 4  Naikin daya prosesnya invalid terus, ngulang b...      1  negative

# %%
df.to_csv('/content/drive/MyDrive/FILE TUGAS AKHIR/PLN 4.csv', index=False)
print("\nPROSES LABELING SELESAI, DATA LABELING SUDAH DIDOWNLOAD, BERIKUT ADALAH DATA LEBALING :")
# Out:
# PROSES LABELING SELESAI, DATA LABELING SUDAH DIDOWNLOAD, BERIKUT ADALAH DATA LEBALING :

# %%
# KARENA KOLOM SCORE SUDAH TIDAK DIPERLUKAN MAKA AKAN DIHAPUS MENGGUNAKAN KODE DIBAWAH INI
# Selanjutnya saya akan menghilangkan data frame score
import pandas as pd

# Ganti dengan path file CSV yang ingin Anda olah
file_path = '/content/drive/MyDrive/FILE TUGAS AKHIR/PLN 4.csv'

# Baca file CSV ke dalam DataFrame
PLN = pd.read_csv(file_path)

# Tampilkan DataFrame sebelum penghapusan kolom
print("Sebelum Penghapusan Kolom:")
PLN.sample(5)

# HAPUS KOLOM
kolom_yang_ingin_dihilangkan = ['score']

# Hapus kolom yang tidak diperlukan
PLN = df.drop(columns=kolom_yang_ingin_dihilangkan)

print("\nBERIKUT DATA SETELAH DIHILANGKAN KOLOM SCORE :")
PLN.head(5)
# Out:
# Sebelum Penghapusan Kolom:
#
# BERIKUT DATA SETELAH DIHILANGKAN KOLOM SCORE :
#                                              content  sentimen
# 0  Proses transaksinya lama, padahal sudah transf...  negative
# 1  Aplikasi nya sudah bagus, memudahkan kita dala...  positive
# 2  Aplikasi ini sangat memudahkan, bisa di gunaka...  positive
# 3  Aplikasi serta pelayanan cukup bagus dan sigap...  positive
# 4  Naikin daya prosesnya invalid terus, ngulang b...  negative

# %%
PLN.to_csv('/content/drive/MyDrive/FILE TUGAS AKHIR/PLN 5.csv', index=False)
print("\nPROSES LABELING SELESAI, DATA LABELING SUDAH DIDOWNLOAD, BERIKUT ADALAH DATA LEBALING :")
# Out:
# PROSES LABELING SELESAI, DATA LABELING SUDAH DIDOWNLOAD, BERIKUT ADALAH DATA LEBALING :

# %%
# BERIKUT VISUALISASI DIAGRAM PERBANDINGAN SENTIMEN NEGATIF DAN POSITIF
import pandas as pd
import matplotlib.pyplot as plt

# Baca data dari file CSV
df = pd.read_csv('/content/drive/MyDrive/FILE TUGAS AKHIR/PLN 5.csv')

# Hitung jumlah setiap Sentimen
sentiment_counts = df['sentimen'].value_counts()

# Gambar diagram lingkaran
plt.figure(figsize=(5, 3))
plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Jumlah sentimen')
plt.axis('equal')  # Membuat lingkaran menjadi bentuk lingkaran sempurna
plt.show()

# %%
# DIBAWAH INI MERUPAKAN KODE UNTUK MENAMPILKAN BERAPA JUMLAH SENTIMEN NEGATIF DAN POSITIF
import pandas as pd

# Baca file CSV
file_path = ('/content/drive/MyDrive/FILE TUGAS AKHIR/PLN 5.csv')
df = pd.read_csv(file_path)

# Pastikan kolom 'sentiment' ada dalam DataFrame
if 'sentimen' in df.columns:
    # Hitung jumlah label positif dan negatif
    label_counts = df['sentimen'].value_counts()

    # Pisahkan jumlah positif dan negatif
    jumlah_positif = label_counts.get('positive', 0)
    jumlah_negatif = label_counts.get('negative', 0)
    print("BERIKUT ADALAH JUMLAH ULASAN PADA LABEL NEGATIF DAN POSITIF :")
    print(f"Jumlah label positif: {jumlah_positif}")
    print(f"Jumlah label negatif: {jumlah_negatif}")
else:
    print("Kolom 'sentiment' tidak ditemukan dalam file CSV.")
# Out:
# BERIKUT ADALAH JUMLAH ULASAN PADA LABEL NEGATIF DAN POSITIF :
# Jumlah label positif: 36546
# Jumlah label negatif: 3497

# %% [markdown]
# **PRE-PROCESSING**

# %%
# MENYIAPKAN DATA YANG AKAN DIGUNAKAN UNTUK PRE-PROCESSING
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/FILE TUGAS AKHIR/PLN 5.csv')
data.head(10)
# Out:
#                                              content  sentimen
# 0  Proses transaksinya lama, padahal sudah transf...  negative
# 1  Aplikasi nya sudah bagus, memudahkan kita dala...  positive
# 2  Aplikasi ini sangat memudahkan, bisa di gunaka...  positive
# 3  Aplikasi serta pelayanan cukup bagus dan sigap...  positive
# 4  Naikin daya prosesnya invalid terus, ngulang b...  negative
# 5  Lebih mudah dalam melihat informasi mengenai i...  positive
# 6  Secara desain UI sudah sangat baik dan bagus d...  positive
# 7  Hello PLN Mobile, ini saya mau sedikit komplan...  negative
# 8  Pelayanan Pembayaran melalui Aplikasi PLN Mobi...  negative
# 9  Tolong UX nya buat lebih mudah lagi.. saya pak...  positive

# %% [markdown]
# **DATA CLEANSING & CASE FOLDING**

# %%
import re
def  clean_text(df, text_field, new_text_field_name):
    data[new_text_field_name] = data[text_field].str.lower()
    data[new_text_field_name] = data[new_text_field_name].apply(lambda elem: re.sub(r"(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", elem))
    # remove numbers
    data[new_text_field_name] = data[new_text_field_name].apply(lambda elem: re.sub(r"\d+", "", elem))
    return data

# %%
data['CASE FOLDING'] = data['content'].str.lower()
data['CASE FOLDING']
data_clean = clean_text(data, 'content', 'CASE FOLDING')
data_clean.head(5)
# Out:
#                                              content  sentimen  \
# 0  Proses transaksinya lama, padahal sudah transf...  negative
# 1  Aplikasi nya sudah bagus, memudahkan kita dala...  positive
# 2  Aplikasi ini sangat memudahkan, bisa di gunaka...  positive
# 3  Aplikasi serta pelayanan cukup bagus dan sigap...  positive
# 4  Naikin daya prosesnya invalid terus, ngulang b...  negative
#
#                                         CASE FOLDING
# 0  proses transaksinya lama padahal sudah transfe...
# 1  aplikasi nya sudah bagus memudahkan kita dalam...
# 2  aplikasi ini sangat memudahkan bisa di gunakan...
# 3  aplikasi serta pelayanan cukup bagus dan sigap...
# 4  naikin daya prosesnya invalid terus ngulang be...

# %%
# Simpan DataFrame yang sudah diubah kembali ke file CSV jika perlu
data_clean.to_csv('/content/drive/MyDrive/FILE TUGAS AKHIR/PLN 6.csv', index=False) # Jika Anda ingin menyimpannya kembali ke file CSV

# %% [markdown]
# **TOKENISASI**

# %%
# tokenisasi menggunakan nltk
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
# Baca data dari file CSV
df = pd.read_csv('/content/drive/MyDrive/FILE TUGAS AKHIR/PLN 6.csv')  # Ganti 'data.csv' dengan nama file CSV Anda

# Contoh fungsi untuk tokenisasi
def tokenize_text(text):
    tokens = word_tokenize(text)  # Tokenisasi menggunakan NLTK

    # Mengembalikan list token
    return tokens

# Terapkan tokenisasi ke kolom 'text'
df['TOKENIZING'] = df['CASE FOLDING'].apply(tokenize_text)

# Tampilkan hasil tokenisasi
df.head(5)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                              content  sentimen  \
# 0  Proses transaksinya lama, padahal sudah transf...  negative
# 1  Aplikasi nya sudah bagus, memudahkan kita dala...  positive
# 2  Aplikasi ini sangat memudahkan, bisa di gunaka...  positive
# 3  Aplikasi serta pelayanan cukup bagus dan sigap...  positive
# 4  Naikin daya prosesnya invalid terus, ngulang b...  negative
#
#                                         CASE FOLDING  \
# 0  proses transaksinya lama padahal sudah transfe...
# 1  aplikasi nya sudah bagus memudahkan kita dalam...
# 2  aplikasi ini sangat memudahkan bisa di gunakan...
# 3  aplikasi serta pelayanan cukup bagus dan sigap...
# 4  naikin daya prosesnya invalid terus ngulang be...
#
# ...

# %%
# Simpan DataFrame yang sudah diubah kembali ke file CSV jika perlu
data_clean.to_csv('/content/drive/MyDrive/FILE TUGAS AKHIR/PLN 7.csv', index=False) # Jika Anda ingin menyimpannya kembali ke file CSV

# %% [markdown]
# **STOPWORD**

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

list_stopwords = stopwords.words('indonesian')
# read txt stopword using pandas
txt_stopword = pd.read_csv("/content/drive/MyDrive/FILE TUGAS AKHIR/PLN 7.csv", names= ["stopwords"], header = None)

# convert stopword string to list & append additional stopword
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))

# convert list to dictionary
list_stopwords = set(list_stopwords)

#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

# Terapkan tokenisasi ke kolom 'text'
df['STOPWORD'] = df['TOKENIZING'].apply(stopwords_removal)
# Tampilkan hasil tokenisasi
df.head(5)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# <ipython-input-12-917471af951c>:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))
#                                              content  sentimen  \
# 0  Proses transaksinya lama, padahal sudah transf...  negative
# 1  Aplikasi nya sudah bagus, memudahkan kita dala...  positive
# 2  Aplikasi ini sangat memudahkan, bisa di gunaka...  positive
# 3  Aplikasi serta pelayanan cukup bagus dan sigap...  positive
# 4  Naikin daya prosesnya invalid terus, ngulang b...  negative
#
#                                         CASE FOLDING  \
# 0  proses transaksinya lama padahal sudah transfe...
# ...

# %% [markdown]
# **STEMMING**

# %%
# INI ADALAH MEMPERSIAPKAN LIBRARY SASTRAWI UNTUK STEMMING
# !pip install Sastrawi
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 14.9 MB/s eta 0:00:00
# ...

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
def stemming(text):
   if isinstance(text, list):
    text = ' '.join(text)
    return ' '.join([stemmer.stem(word) for word in text.split()])

# Menambahkan kolom hasil stemming
df['STEMMING'] = df['STOPWORD'].apply(stemming)
print("\nHASIL STEMMING :")
df[['content', 'CASE FOLDING', 'TOKENIZING', 'STOPWORD', 'STEMMING']].head(5)
# Out:
# HASIL STEMMING :
#                                              content  \
# 0  Proses transaksinya lama, padahal sudah transf...
# 1  Aplikasi nya sudah bagus, memudahkan kita dala...
# 2  Aplikasi ini sangat memudahkan, bisa di gunaka...
# 3  Aplikasi serta pelayanan cukup bagus dan sigap...
# 4  Naikin daya prosesnya invalid terus, ngulang b...
#
#                                         CASE FOLDING  \
# 0  proses transaksinya lama padahal sudah transfe...
# 1  aplikasi nya sudah bagus memudahkan kita dalam...
# 2  aplikasi ini sangat memudahkan bisa di gunakan...
# 3  aplikasi serta pelayanan cukup bagus dan sigap...
# 4  naikin daya prosesnya invalid terus ngulang be...
#
#                                           TOKENIZING  \
# 0  [proses, transaksinya, lama, padahal, sudah, t...
# 1  [aplikasi, nya, sudah, bagus, memudahkan, kita...
# 2  [aplikasi, ini, sangat, memudahkan, bisa, di, ...
# 3  [aplikasi, serta, pelayanan, cukup, bagus, dan...
# ...

# %%
# Menyimpan hasil preprocessing ke dalam file CSV
df.to_csv('/content/drive/MyDrive/FILE TUGAS AKHIR/PLN 8.csv', index=False)

# %%
# MENGHILANGKAN BARIS YANG TIDAK ADA KALIMAT
import pandas as pd

# Membaca data dari file CSV
df = pd.read_csv('/content/drive/MyDrive/FILE TUGAS AKHIR/PLN 8.csv')

# Menghapus baris dengan nilai NaN atau teks kosong pada kolom 'stemming'
df_cleaned = df.dropna(subset=['STEMMING'])
df_cleaned = df_cleaned[df_cleaned['STEMMING'].str.strip().ne('')]

# Menyimpan DataFrame yang sudah dibersihkan ke file CSV baru
df_cleaned.to_csv('/content/drive/MyDrive/FILE TUGAS AKHIR/PLN 9.csv', index=False)

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39972 entries, 0 to 40042
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   content       39972 non-null  object
#  1   sentimen      39972 non-null  object
#  2   CASE FOLDING  39972 non-null  object
#  3   TOKENIZING    39972 non-null  object
#  4   STOPWORD      39972 non-null  object
#  5   STEMMING      39972 non-null  object
# dtypes: object(6)
# memory usage: 2.1+ MB

# %% [markdown]
# **WORD FREQUENCY**

# %%
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Membaca file CSV
df = pd.read_csv('/content/drive/MyDrive/FILE TUGAS AKHIR/PLN 9.csv')  # Ganti 'nama_file.csv' dengan nama file CSV Anda

# Menggabungkan semua teks dalam satu kolom menjadi satu string
all_text = ' '.join(df['STEMMING'])  # Ganti 'kolom_teks' dengan nama kolom yang berisi teks

# Tokenisasi dan hapus stopwords
stop_words = set(stopwords.words('indonesian'))  # Anda bisa mengganti 'english' dengan bahasa lain jika diperlukan
tokens = word_tokenize(all_text.lower())
filtered_tokens = [word for word in tokens if word.isalnum() and word not in stop_words]

# Menghitung frekuensi kata
word_freq = Counter(filtered_tokens)

# Menampilkan frekuensi kata
for word, freq in word_freq.most_common(20):  # Menampilkan 10 kata yang paling sering muncul
    print(f'{word}: {freq}')

# Memilih 20 kata yang paling sering muncul
most_common_words = word_freq.most_common(20)

# Memisahkan kata dan frekuensinya
words, frequencies = zip(*most_common_words)

# Membuat visualisasi
plt.figure(figsize=(10, 6))
sns.barplot(x=frequencies, y=words, palette='viridis')

# Menambahkan label dan judul
plt.title('20 Kata yang Paling Sering Muncul')
plt.xlabel('Frekuensi')
plt.ylabel('Kata')

# Menampilkan visualisasi
plt.show()
# Out:
# pln: 15711
# aplikasi: 11961
# bantu: 10756
# mudah: 7349
# layan: 7160
# cepat: 6780
# mobile: 6650
# listrik: 4578
# bagus: 3960
# nya: 3822
# mantap: 3030
# adu: 2695
# yg: 2600
# kasih: 2552
# bayar: 2374
# tugas: 2341
# respon: 2195
# terimakasih: 2194
# langgan: 2068
# terima: 1968
# <ipython-input-20-ffc399ccd17d>:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=frequencies, y=words, palette='viridis')

# %%
# !pip install wordcloud pandas

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd

# Baca file CSV
file_path = '/content/drive/MyDrive/FILE TUGAS AKHIR/PLN 9.csv'  # Ganti dengan path file CSV Anda
data = pd.read_csv(file_path)

# Gabungkan semua teks menjadi satu string
all_texts = ' '.join(data['STEMMING'])  # Ganti 'content' dengan nama kolom teks di file CSV Anda

# Buat objek WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_texts)

# Tampilkan word cloud menggunakan matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# **DATA SPLITTING**

# %%
import numpy as np
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/FILE TUGAS AKHIR/PLN 9.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39972 entries, 0 to 39971
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   content       39972 non-null  object
#  1   sentimen      39972 non-null  object
#  2   CASE FOLDING  39972 non-null  object
#  3   TOKENIZING    39972 non-null  object
#  4   STOPWORD      39972 non-null  object
#  5   STEMMING      39972 non-null  object
# dtypes: object(6)
# memory usage: 1.8+ MB

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Membaca data dari file CSV
df = pd.read_csv('/content/drive/MyDrive/FILE TUGAS AKHIR/PLN 9.csv')

# Misalkan kolom 'stemming' berisi teks dan 'sentiment' berisi label sentimen
texts = df['STEMMING'].values
labels = df['sentimen'].values

# Membagi data menjadi data pelatihan dan pengujian
X_train, X_test, y_train, y_test = train_test_split(texts, labels, test_size=0.2, random_state=42)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Parameter
max_words = 10000
max_len = 100

# Tokenisasi
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(X_train)
X_train_seq = tokenizer.texts_to_sequences(X_train)
X_test_seq = tokenizer.texts_to_sequences(X_test)

# Padding
X_train_pad = pad_sequences(X_train_seq, maxlen=max_len)
X_test_pad = pad_sequences(X_test_seq, maxlen=max_len)

# %%
import numpy as np

print(X_train_pad.shape, X_test_pad.shape)
print(np.unique(y_train), np.unique(y_test))
# Out:
# (31977, 100) (7995, 100)
# ['negative' 'positive'] ['negative' 'positive']

# %% [markdown]
# **MEMBANGUN MODEL LSTM**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, SpatialDropout1D
from tensorflow.keras.optimizers import Adam

# Define model
model = Sequential()
model.add(Embedding(input_dim=max_words, output_dim=128, input_length=max_len))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(100))
model.add(Dense(1, activation='sigmoid'))

# Compile model
model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 100, 128)          1280000
#
#  spatial_dropout1d (Spatial  (None, 100, 128)          0
#  Dropout1D)
#
#  lstm (LSTM)                 (None, 100)               91600
#
#  dense (Dense)               (None, 1)                 101
#
# ...
# Total params: 1371701 (5.23 MB)
# Trainable params: 1371701 (5.23 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
# MENGUBAH LABEL POSITIVE DAN NEGATIVE MENJADI NUMERIK
from sklearn.preprocessing import LabelEncoder

# Encode labels
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Pastikan label sudah dalam format integer
print(np.unique(y_train_encoded))
print(np.unique(y_test_encoded))
# Out:
# [0 1]
# [0 1]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, SpatialDropout1D
from tensorflow.keras.optimizers import Adam

# Definisikan model
model = Sequential()
model.add(Embedding(input_dim=max_words, output_dim=128, input_length=max_len))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(100))
model.add(Dense(1, activation='sigmoid'))

# Kompilasi model
model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# Ringkasan model
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_1 (Embedding)     (None, 100, 128)          1280000
#
#  spatial_dropout1d_1 (Spati  (None, 100, 128)          0
#  alDropout1D)
#
#  lstm_1 (LSTM)               (None, 100)               91600
#
#  dense_1 (Dense)             (None, 1)                 101
#
# ...
# Total params: 1371701 (5.23 MB)
# Trainable params: 1371701 (5.23 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **TRAINING MODEL**

# %%
import numpy as np

# Data dummy
X_train_dummy = np.random.randint(10000, size=(100, max_len))
X_test_dummy = np.random.randint(10000, size=(20, max_len))
y_train_dummy = np.random.randint(2, size=(100,))
y_test_dummy = np.random.randint(2, size=(20,))

# Fit model dengan data dummy
history = model.fit(X_train_dummy, y_train_dummy, epochs=5, batch_size=32, validation_data=(X_test_dummy, y_test_dummy))
# Out:
# Epoch 1/5
# 4/4 [==============================] - 4s 272ms/step - loss: 0.6928 - accuracy: 0.5000 - val_loss: 0.6925 - val_accuracy: 0.5000
# Epoch 2/5
# 4/4 [==============================] - 0s 100ms/step - loss: 0.6804 - accuracy: 0.6300 - val_loss: 0.6917 - val_accuracy: 0.5500
# Epoch 3/5
# 4/4 [==============================] - 0s 117ms/step - loss: 0.6588 - accuracy: 0.8700 - val_loss: 0.6921 - val_accuracy: 0.5500
# Epoch 4/5
# 4/4 [==============================] - 1s 159ms/step - loss: 0.6056 - accuracy: 1.0000 - val_loss: 0.6930 - val_accuracy: 0.5500
# Epoch 5/5
# 4/4 [==============================] - 1s 182ms/step - loss: 0.4576 - accuracy: 0.8900 - val_loss: 0.7123 - val_accuracy: 0.5500

# %%
# MENGGANTI MODEL TRAINING KARENA TRAINING SEBELUMNYA DARI EPOCHS 1 - 5 MENGALAMI OVERFITTING YANG SIGNIFIKAN
# DAN TRAINING SEBELUMNYA AKURASI TERLALU RENDAH
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# Latih model di CPU
history = model.fit(X_train_pad, y_train_encoded, epochs=5, batch_size=32, validation_data=(X_test_pad, y_test_encoded))
# Out:
# Epoch 1/5
# 1000/1000 [==============================] - 134s 132ms/step - loss: 0.1516 - accuracy: 0.9360 - val_loss: 0.1298 - val_accuracy: 0.9436
# Epoch 2/5
# 1000/1000 [==============================] - 142s 141ms/step - loss: 0.1071 - accuracy: 0.9571 - val_loss: 0.1247 - val_accuracy: 0.9472
# Epoch 3/5
# 1000/1000 [==============================] - 137s 137ms/step - loss: 0.0826 - accuracy: 0.9688 - val_loss: 0.1343 - val_accuracy: 0.9468
# Epoch 4/5
# 1000/1000 [==============================] - 128s 128ms/step - loss: 0.0665 - accuracy: 0.9763 - val_loss: 0.1415 - val_accuracy: 0.9457
# Epoch 5/5
# 1000/1000 [==============================] - 129s 129ms/step - loss: 0.0545 - accuracy: 0.9812 - val_loss: 0.1574 - val_accuracy: 0.9462

# %%
import matplotlib.pyplot as plt

# Memulai pelatihan model
#history = model.fit(X_train_pad, y_train_encoded, epochs=5, batch_size=32, validation_data=(X_test_pad, y_test_encoded))

plt.figure(figsize=(12, 4))


# Plotting Training & Validation Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.yticks([0.2, 0.4, 0.6, 0.8, 0.9, 1.0])
plt.show()

# %%
model.save('/content/drive/MyDrive/FILE TUGAS AKHIR/LSTM ALGORITM.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# **PENGUJIAN**

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Prediksi
y_pred = (model.predict(X_test_pad) > 0.5).astype('int32')

# Classification report
print(classification_report(y_test_encoded, y_pred, target_names=['negative', 'positive']))

# Confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test_encoded, y_pred)
plt.figure(figsize=(4, 3))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['negative', 'positive'], yticklabels=['negative', 'positive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 250/250 [==============================] - 7s 27ms/step
#               precision    recall  f1-score   support
#
#     negative       0.70      0.64      0.67       677
#     positive       0.97      0.97      0.97      7318
#
#     accuracy                           0.95      7995
#    macro avg       0.83      0.81      0.82      7995
# weighted avg       0.94      0.95      0.95      7995

# %% [markdown]
# **MENCOBA MENGGUNAKAN TRAINING GPU DILAKUKAN DI CPU**

# %%
# Atur konfigurasi GPU jika diperlukan
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        # Mengatur batas memori GPU jika diperlukan
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# %%
# Latih model di GPU
history = model.fit(X_train_pad, y_train_encoded, epochs=5, batch_size=64, validation_data=(X_test_pad, y_test_encoded))
# Out:
# Epoch 1/5
# 500/500 [==============================] - 103s 206ms/step - loss: 0.0421 - accuracy: 0.9856 - val_loss: 0.1854 - val_accuracy: 0.9446
# Epoch 2/5
# 500/500 [==============================] - 96s 192ms/step - loss: 0.0362 - accuracy: 0.9882 - val_loss: 0.2034 - val_accuracy: 0.9456
# Epoch 3/5
# 500/500 [==============================] - 129s 258ms/step - loss: 0.0333 - accuracy: 0.9898 - val_loss: 0.1916 - val_accuracy: 0.9418
# Epoch 4/5
# 500/500 [==============================] - 104s 209ms/step - loss: 0.0308 - accuracy: 0.9900 - val_loss: 0.2158 - val_accuracy: 0.9460
# Epoch 5/5
# 500/500 [==============================] - 94s 188ms/step - loss: 0.0285 - accuracy: 0.9917 - val_loss: 0.2302 - val_accuracy: 0.9440

# %%
model.save('/content/drive/MyDrive/FILE TUGAS AKHIR/LSTM ALGORITM GPU RUNTIME.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# **PENGUJIAN**

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Prediksi pada data pengujian
y_pred = (model.predict(X_test_pad) > 0.5).astype('int32')

# Classification report
print(classification_report(y_test_encoded, y_pred, target_names=['negative', 'positive']))

# Confusion matrix
cm = confusion_matrix(y_test_encoded, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['negative', 'positive'], yticklabels=['negative', 'positive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 250/250 [==============================] - 10s 38ms/step
#               precision    recall  f1-score   support
#
#     negative       0.68      0.64      0.66       677
#     positive       0.97      0.97      0.97      7318
#
#     accuracy                           0.94      7995
#    macro avg       0.82      0.81      0.82      7995
# weighted avg       0.94      0.94      0.94      7995
